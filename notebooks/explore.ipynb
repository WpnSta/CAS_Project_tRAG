# %% [markdown]
# # FDV Corpus Exploration
# Terminology and vocabulary analysis across DE / FR / IT language versions.

# %% [markdown]
# ## Section 0 — Imports & Configuration

# %%
# %pip install -q sentence-transformers chromadb rank-bm25 langdetect ollama \
             scikit-learn pandas matplotlib stop-words requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\niw\Documents\CAS_NLP_Project\Project_tRAG\.venv\Scripts\python.exe: No module named pip

# %%
import re
import json
import urllib.request
import urllib.parse
from collections import Counter
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.feature_extraction.text import TfidfVectorizer

from chunking import (
    load_documents, build_chunk_records,
    CHUNK_MIN_CHARS, CHUNK_MAX_CHARS
)

# ── Configuration ──────────────────────────────────────────────────────────
LANGUAGES  = ["de", "fr", "it"]
DATA_DIRS  = {
    "de": Path("data/de"),
    "fr": Path("data/fr"),
    "it": Path("data/it"),
}

# Set to True to fetch Wikipedia reference articles (requires internet access)
FETCH_WIKIPEDIA = True

# ── Stopword sets (hardcoded, common function words per language) ───────────
STOPWORDS = {
    "de": {
        "dass", "auch", "wird", "werden", "sind", "eine", "einer", "einem", "eines",
        "einen", "dieser", "diese", "diesem", "diesen", "nach", "beim",
        "durch", "oder", "über", "unter", "nicht", "wenn", "kann", "muss",
        "müssen", "darf", "haben", "sein", "sein", "wurde", "worden", "soweit",
        "sowie", "dabei", "daher", "damit", "dazu", "beim", "ihre", "ihren",
        "ihrer", "ihrem", "sowie", "jedoch", "falls", "sowohl", "werden",
        "welche", "welchen", "welchem", "welcher", "immer", "bereits", "noch",
        "mehr", "sehr", "hier", "dort", "dann", "erst", "zwar", "werden", "sich",
        "kein", "keine", "keines", "keinem",
    },
    "fr": {
        "dans", "pour", "avec", "sont", "cette", "tout", "plus", "doit",
        "doivent", "être", "avoir", "sera", "leur", "leurs", "bien", "même",
        "dont", "lors", "afin", "ainsi", "selon", "entre", "peut", "peuvent",
        "aussi", "donc", "mais", "comme", "toute", "tous", "toutes", "sans",
        "sous", "avant", "après", "vers", "chez", "soit", "autre", "autres",
        "lors", "celui", "celle", "ceux", "celles", "quand", "alors", "plus",
        "faut",
    },
    "it": {
        "sono", "viene", "deve", "devono", "essere", "dalla", "dello", "degli",
        "delle", "nella", "negli", "nelle", "anche", "ogni", "questo", "questi",
        "alla", "alle", "agli", "durante", "mentre", "prima", "dopo", "sempre",
        "però", "oppure", "senza", "quando", "come", "perché", "quindi",
        "quella", "quelli", "quelle", "quale", "quali", "tale", "tali",
        "solo", "solo", "altre", "altri", "altra", "altro", "molti", "molto",
        "dell", "della",
    },
}

# Tokenizer for exploration: lowercase, 4+ chars, Latin-extended range
TOKEN_RE = re.compile(r"[a-z\u00c0-\u024f]{4,}")

def tokenize(text: str) -> list:
    return TOKEN_RE.findall(text.lower())

def content_words(tokens: list, lang: str) -> list:
    stops = STOPWORDS.get(lang, set())
    return [t for t in tokens if t not in stops]

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %%
# Load all documents and build chunk records
all_docs = []
for lang in LANGUAGES:
    docs = load_documents(DATA_DIRS[lang], lang)
    all_docs.extend(docs)
    print(f"  {lang}: {len(docs)} documents")

chunk_records = build_chunk_records(all_docs)

# Organise by language for convenience
docs_by_lang   = {lang: [d for d in all_docs      if d["language"] == lang] for lang in LANGUAGES}
chunks_by_lang = {lang: [c for c in chunk_records if c["language"] == lang] for lang in LANGUAGES}

print(f"\nTotal documents : {len(all_docs)}")
print(f"Total chunks    : {len(chunk_records)}")
# Out:
#   de: 15 documents
#   fr: 15 documents
#   it: 15 documents
#
# Total documents : 45
# Total chunks    : 4218

# %%
# Diagnostic: how many chunks are below CHUNK_MIN_CHARS and why?
short = [r for r in chunk_records if len(r["text"]) < CHUNK_MIN_CHARS]
print(f"Chunks below CHUNK_MIN_CHARS ({CHUNK_MIN_CHARS}): {len(short)} of {len(chunk_records)} "
      f"({100*len(short)/len(chunk_records):.1f}%)")

by_lang = {}
for r in short:
    by_lang[r["language"]] = by_lang.get(r["language"], 0) + 1
for lang, count in sorted(by_lang.items()):
    print(f"  {lang}: {count} short chunks")

print("\nSample short chunks:")
for r in short[:5]:
    print(f"\n  [{r['regulation_number']} §{r.get('section_id','')}] "
          f"len={len(r['text'])} chars")
    print(f"  {repr(r['text'][:120])}")
# Out:
# Chunks below CHUNK_MIN_CHARS (150): 0 of 4218 (0.0%)
#
# Sample short chunks:

# %% [markdown]
# ## Section 1 — Document Overview

# %%
for lang in LANGUAGES:
    rows = []
    for doc in docs_by_lang[lang]:
        doc_chunks = [c for c in chunks_by_lang[lang]
                      if c["source_file"] == doc["source_file"]]
        rows.append({
            "Regulation":  doc["regulation_number"],
            "Title":       doc["document_title"],
            "Characters":  len(doc["text"]),
            "Words":       len(doc["text"].split()),
            "Chunks":      len(doc_chunks),
        })
    df = pd.DataFrame(rows).sort_values("Regulation")
    totals = pd.DataFrame([{
        "Regulation": "TOTAL",
        "Title": "",
        "Characters": df["Characters"].sum(),
        "Words":      df["Words"].sum(),
        "Chunks":     df["Chunks"].sum(),
    }])
    df_display = pd.concat([df, totals], ignore_index=True)

    print(f"\n{'='*60}")
    print(f"  Language: {lang.upper()}")
    print(f"{'='*60}")
    display(df_display.style.hide(axis="index"))

    # Horizontal bar chart
    fig, ax = plt.subplots(figsize=(8, 4))
    df_sorted = df.sort_values("Characters")
    ax.barh(df_sorted["Regulation"], df_sorted["Characters"], color="steelblue")
    ax.set_xlabel("Characters")
    ax.set_title(f"Document size — {lang.upper()}")
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{int(x):,}"))
    plt.tight_layout()
    plt.show()
# Out:
# ============================================================
#   Language: DE
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_f3e16">
#   <thead>
#     <tr>
#       <th id="T_f3e16_level0_col0" class="col_heading level0 col0" >Regulation</th>
#       <th id="T_f3e16_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_f3e16_level0_col2" class="col_heading level0 col2" >Characters</th>
#       <th id="T_f3e16_level0_col3" class="col_heading level0 col3" >Words</th>
#       <th id="T_f3e16_level0_col4" class="col_heading level0 col4" >Chunks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3e16_row0_col0" class="data row0 col0" >R 300.1</td>
#       <td id="T_f3e16_row0_col1" class="data row0 col1" >Grundlagen</td>
#       <td id="T_f3e16_row0_col2" class="data row0 col2" >45652</td>
#       <td id="T_f3e16_row0_col3" class="data row0 col3" >5635</td>
#       <td id="T_f3e16_row0_col4" class="data row0 col4" >91</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row1_col0" class="data row1 col0" >R 300.10</td>
#       <td id="T_f3e16_row1_col1" class="data row1 col1" >Formulare</td>
#       <td id="T_f3e16_row1_col2" class="data row1 col2" >4013</td>
#       <td id="T_f3e16_row1_col3" class="data row1 col3" >533</td>
#       <td id="T_f3e16_row1_col4" class="data row1 col4" >11</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row2_col0" class="data row2 col0" >R 300.11</td>
#       <td id="T_f3e16_row2_col1" class="data row2 col1" >Schalten und Erden von Fahrleitungen</td>
#       <td id="T_f3e16_row2_col2" class="data row2 col2" >4894</td>
#       <td id="T_f3e16_row2_col3" class="data row2 col3" >598</td>
#       <td id="T_f3e16_row2_col4" class="data row2 col4" >11</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row3_col0" class="data row3 col0" >R 300.12</td>
#       <td id="T_f3e16_row3_col1" class="data row3 col1" >Arbeiten im Gleisbereich</td>
#       <td id="T_f3e16_row3_col2" class="data row3 col2" >37039</td>
#       <td id="T_f3e16_row3_col3" class="data row3 col3" >4841</td>
#       <td id="T_f3e16_row3_col4" class="data row3 col4" >103</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row4_col0" class="data row4 col0" >R 300.13</td>
#       <td id="T_f3e16_row4_col1" class="data row4 col1" >Lokfuehrer in</td>
#       <td id="T_f3e16_row4_col2" class="data row4 col2" >15839</td>
#       <td id="T_f3e16_row4_col3" class="data row4 col3" >2053</td>
#       <td id="T_f3e16_row4_col4" class="data row4 col4" >46</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row5_col0" class="data row5 col0" >R 300.14</td>
#       <td id="T_f3e16_row5_col1" class="data row5 col1" >Bremsen</td>
#       <td id="T_f3e16_row5_col2" class="data row5 col2" >67096</td>
#       <td id="T_f3e16_row5_col3" class="data row5 col3" >8675</td>
#       <td id="T_f3e16_row5_col4" class="data row5 col4" >144</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row6_col0" class="data row6 col0" >R 300.15</td>
#       <td id="T_f3e16_row6_col1" class="data row6 col1" >Besondere Betriebsformen</td>
#       <td id="T_f3e16_row6_col2" class="data row6 col2" >11069</td>
#       <td id="T_f3e16_row6_col3" class="data row6 col3" >1470</td>
#       <td id="T_f3e16_row6_col4" class="data row6 col4" >27</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row7_col0" class="data row7 col0" >R 300.2</td>
#       <td id="T_f3e16_row7_col1" class="data row7 col1" >Signale</td>
#       <td id="T_f3e16_row7_col2" class="data row7 col2" >88160</td>
#       <td id="T_f3e16_row7_col3" class="data row7 col3" >10819</td>
#       <td id="T_f3e16_row7_col4" class="data row7 col4" >210</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row8_col0" class="data row8 col0" >R 300.3</td>
#       <td id="T_f3e16_row8_col1" class="data row8 col1" >Kommunikation Anordnungen und Uebermittlung</td>
#       <td id="T_f3e16_row8_col2" class="data row8 col2" >44399</td>
#       <td id="T_f3e16_row8_col3" class="data row8 col3" >5603</td>
#       <td id="T_f3e16_row8_col4" class="data row8 col4" >104</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row9_col0" class="data row9 col0" >R 300.4</td>
#       <td id="T_f3e16_row9_col1" class="data row9 col1" >Rangierbewegungen</td>
#       <td id="T_f3e16_row9_col2" class="data row9 col2" >93109</td>
#       <td id="T_f3e16_row9_col3" class="data row9 col3" >12225</td>
#       <td id="T_f3e16_row9_col4" class="data row9 col4" >212</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row10_col0" class="data row10 col0" >R 300.5</td>
#       <td id="T_f3e16_row10_col1" class="data row10 col1" >Zugvorbereitung</td>
#       <td id="T_f3e16_row10_col2" class="data row10 col2" >46468</td>
#       <td id="T_f3e16_row10_col3" class="data row10 col3" >6195</td>
#       <td id="T_f3e16_row10_col4" class="data row10 col4" >101</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row11_col0" class="data row11 col0" >R 300.6</td>
#       <td id="T_f3e16_row11_col1" class="data row11 col1" >Zugfahrten</td>
#       <td id="T_f3e16_row11_col2" class="data row11 col2" >41548</td>
#       <td id="T_f3e16_row11_col3" class="data row11 col3" >5347</td>
#       <td id="T_f3e16_row11_col4" class="data row11 col4" >108</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row12_col0" class="data row12 col0" >R 300.7</td>
#       <td id="T_f3e16_row12_col1" class="data row12 col1" >Zugbeeinflussung</td>
#       <td id="T_f3e16_row12_col2" class="data row12 col2" >5853</td>
#       <td id="T_f3e16_row12_col3" class="data row12 col3" >716</td>
#       <td id="T_f3e16_row12_col4" class="data row12 col4" >14</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row13_col0" class="data row13 col0" >R 300.8</td>
#       <td id="T_f3e16_row13_col1" class="data row13 col1" >Arbeitssicherheit</td>
#       <td id="T_f3e16_row13_col2" class="data row13 col2" >8979</td>
#       <td id="T_f3e16_row13_col3" class="data row13 col3" >1131</td>
#       <td id="T_f3e16_row13_col4" class="data row13 col4" >18</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row14_col0" class="data row14 col0" >R 300.9</td>
#       <td id="T_f3e16_row14_col1" class="data row14 col1" >Stoerungen</td>
#       <td id="T_f3e16_row14_col2" class="data row14 col2" >66715</td>
#       <td id="T_f3e16_row14_col3" class="data row14 col3" >8912</td>
#       <td id="T_f3e16_row14_col4" class="data row14 col4" >151</td>
#     </tr>
#     <tr>
#       <td id="T_f3e16_row15_col0" class="data row15 col0" >TOTAL</td>
#       <td id="T_f3e16_row15_col1" class="data row15 col1" ></td>
#       <td id="T_f3e16_row15_col2" class="data row15 col2" >580833</td>
#       <td id="T_f3e16_row15_col3" class="data row15 col3" >74753</td>
#       <td id="T_f3e16_row15_col4" class="data row15 col4" >1351</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   Language: FR
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_e7ddb">
#   <thead>
#     <tr>
#       <th id="T_e7ddb_level0_col0" class="col_heading level0 col0" >Regulation</th>
#       <th id="T_e7ddb_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_e7ddb_level0_col2" class="col_heading level0 col2" >Characters</th>
#       <th id="T_e7ddb_level0_col3" class="col_heading level0 col3" >Words</th>
#       <th id="T_e7ddb_level0_col4" class="col_heading level0 col4" >Chunks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e7ddb_row0_col0" class="data row0 col0" >R 300.1</td>
#       <td id="T_e7ddb_row0_col1" class="data row0 col1" >Principes de base</td>
#       <td id="T_e7ddb_row0_col2" class="data row0 col2" >51626</td>
#       <td id="T_e7ddb_row0_col3" class="data row0 col3" >7841</td>
#       <td id="T_e7ddb_row0_col4" class="data row0 col4" >102</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row1_col0" class="data row1 col0" >R 300.10</td>
#       <td id="T_e7ddb_row1_col1" class="data row1 col1" >Formulaires</td>
#       <td id="T_e7ddb_row1_col2" class="data row1 col2" >4278</td>
#       <td id="T_e7ddb_row1_col3" class="data row1 col3" >644</td>
#       <td id="T_e7ddb_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row2_col0" class="data row2 col0" >R 300.11</td>
#       <td id="T_e7ddb_row2_col1" class="data row2 col1" >Enclenchement declenchement et mise a la terre</td>
#       <td id="T_e7ddb_row2_col2" class="data row2 col2" >5796</td>
#       <td id="T_e7ddb_row2_col3" class="data row2 col3" >869</td>
#       <td id="T_e7ddb_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row3_col0" class="data row3 col0" >R 300.12</td>
#       <td id="T_e7ddb_row3_col1" class="data row3 col1" >Travaux sur et aux abords des voies</td>
#       <td id="T_e7ddb_row3_col2" class="data row3 col2" >39238</td>
#       <td id="T_e7ddb_row3_col3" class="data row3 col3" >6131</td>
#       <td id="T_e7ddb_row3_col4" class="data row3 col4" >106</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row4_col0" class="data row4 col0" >R 300.13</td>
#       <td id="T_e7ddb_row4_col1" class="data row4 col1" >Mecanicien ne de locomotive</td>
#       <td id="T_e7ddb_row4_col2" class="data row4 col2" >16972</td>
#       <td id="T_e7ddb_row4_col3" class="data row4 col3" >2694</td>
#       <td id="T_e7ddb_row4_col4" class="data row4 col4" >46</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row5_col0" class="data row5 col0" >R 300.14</td>
#       <td id="T_e7ddb_row5_col1" class="data row5 col1" >Freins</td>
#       <td id="T_e7ddb_row5_col2" class="data row5 col2" >75077</td>
#       <td id="T_e7ddb_row5_col3" class="data row5 col3" >12086</td>
#       <td id="T_e7ddb_row5_col4" class="data row5 col4" >161</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row6_col0" class="data row6 col0" >R 300.15</td>
#       <td id="T_e7ddb_row6_col1" class="data row6 col1" >Formes particulieres d exploitation</td>
#       <td id="T_e7ddb_row6_col2" class="data row6 col2" >11818</td>
#       <td id="T_e7ddb_row6_col3" class="data row6 col3" >1922</td>
#       <td id="T_e7ddb_row6_col4" class="data row6 col4" >28</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row7_col0" class="data row7 col0" >R 300.2</td>
#       <td id="T_e7ddb_row7_col1" class="data row7 col1" >Signaux</td>
#       <td id="T_e7ddb_row7_col2" class="data row7 col2" >103665</td>
#       <td id="T_e7ddb_row7_col3" class="data row7 col3" >15499</td>
#       <td id="T_e7ddb_row7_col4" class="data row7 col4" >236</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row8_col0" class="data row8 col0" >R 300.3</td>
#       <td id="T_e7ddb_row8_col1" class="data row8 col1" >Communication annonces et transmissions</td>
#       <td id="T_e7ddb_row8_col2" class="data row8 col2" >47484</td>
#       <td id="T_e7ddb_row8_col3" class="data row8 col3" >7443</td>
#       <td id="T_e7ddb_row8_col4" class="data row8 col4" >103</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row9_col0" class="data row9 col0" >R 300.4</td>
#       <td id="T_e7ddb_row9_col1" class="data row9 col1" >Mouvements de manoeuvre</td>
#       <td id="T_e7ddb_row9_col2" class="data row9 col2" >103230</td>
#       <td id="T_e7ddb_row9_col3" class="data row9 col3" >16432</td>
#       <td id="T_e7ddb_row9_col4" class="data row9 col4" >239</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row10_col0" class="data row10 col0" >R 300.5</td>
#       <td id="T_e7ddb_row10_col1" class="data row10 col1" >Preparation des trains</td>
#       <td id="T_e7ddb_row10_col2" class="data row10 col2" >52536</td>
#       <td id="T_e7ddb_row10_col3" class="data row10 col3" >8472</td>
#       <td id="T_e7ddb_row10_col4" class="data row10 col4" >108</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row11_col0" class="data row11 col0" >R 300.6</td>
#       <td id="T_e7ddb_row11_col1" class="data row11 col1" >Circulation des trains</td>
#       <td id="T_e7ddb_row11_col2" class="data row11 col2" >45568</td>
#       <td id="T_e7ddb_row11_col3" class="data row11 col3" >7305</td>
#       <td id="T_e7ddb_row11_col4" class="data row11 col4" >114</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row12_col0" class="data row12 col0" >R 300.7</td>
#       <td id="T_e7ddb_row12_col1" class="data row12 col1" >Controle de la marche des trains</td>
#       <td id="T_e7ddb_row12_col2" class="data row12 col2" >6334</td>
#       <td id="T_e7ddb_row12_col3" class="data row12 col3" >983</td>
#       <td id="T_e7ddb_row12_col4" class="data row12 col4" >16</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row13_col0" class="data row13 col0" >R 300.8</td>
#       <td id="T_e7ddb_row13_col1" class="data row13 col1" >Securite au travail</td>
#       <td id="T_e7ddb_row13_col2" class="data row13 col2" >10366</td>
#       <td id="T_e7ddb_row13_col3" class="data row13 col3" >1667</td>
#       <td id="T_e7ddb_row13_col4" class="data row13 col4" >19</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row14_col0" class="data row14 col0" >R 300.9</td>
#       <td id="T_e7ddb_row14_col1" class="data row14 col1" >Derangements</td>
#       <td id="T_e7ddb_row14_col2" class="data row14 col2" >73981</td>
#       <td id="T_e7ddb_row14_col3" class="data row14 col3" >11868</td>
#       <td id="T_e7ddb_row14_col4" class="data row14 col4" >166</td>
#     </tr>
#     <tr>
#       <td id="T_e7ddb_row15_col0" class="data row15 col0" >TOTAL</td>
#       <td id="T_e7ddb_row15_col1" class="data row15 col1" ></td>
#       <td id="T_e7ddb_row15_col2" class="data row15 col2" >647969</td>
#       <td id="T_e7ddb_row15_col3" class="data row15 col3" >101856</td>
#       <td id="T_e7ddb_row15_col4" class="data row15 col4" >1469</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   Language: IT
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_20479">
#   <thead>
#     <tr>
#       <th id="T_20479_level0_col0" class="col_heading level0 col0" >Regulation</th>
#       <th id="T_20479_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_20479_level0_col2" class="col_heading level0 col2" >Characters</th>
#       <th id="T_20479_level0_col3" class="col_heading level0 col3" >Words</th>
#       <th id="T_20479_level0_col4" class="col_heading level0 col4" >Chunks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20479_row0_col0" class="data row0 col0" >R 300.1</td>
#       <td id="T_20479_row0_col1" class="data row0 col1" >Basi</td>
#       <td id="T_20479_row0_col2" class="data row0 col2" >48944</td>
#       <td id="T_20479_row0_col3" class="data row0 col3" >7165</td>
#       <td id="T_20479_row0_col4" class="data row0 col4" >91</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row1_col0" class="data row1 col0" >R 300.10</td>
#       <td id="T_20479_row1_col1" class="data row1 col1" >Formulari</td>
#       <td id="T_20479_row1_col2" class="data row1 col2" >4174</td>
#       <td id="T_20479_row1_col3" class="data row1 col3" >609</td>
#       <td id="T_20479_row1_col4" class="data row1 col4" >11</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row2_col0" class="data row2 col0" >R 300.11</td>
#       <td id="T_20479_row2_col1" class="data row2 col1" >Commutazione e messa a terra di linee di contatto</td>
#       <td id="T_20479_row2_col2" class="data row2 col2" >5345</td>
#       <td id="T_20479_row2_col3" class="data row2 col3" >785</td>
#       <td id="T_20479_row2_col4" class="data row2 col4" >10</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row3_col0" class="data row3 col0" >R 300.12</td>
#       <td id="T_20479_row3_col1" class="data row3 col1" >Lavori nella zona dei binari</td>
#       <td id="T_20479_row3_col2" class="data row3 col2" >38553</td>
#       <td id="T_20479_row3_col3" class="data row3 col3" >5855</td>
#       <td id="T_20479_row3_col4" class="data row3 col4" >102</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row4_col0" class="data row4 col0" >R 300.13</td>
#       <td id="T_20479_row4_col1" class="data row4 col1" >Macchinista</td>
#       <td id="T_20479_row4_col2" class="data row4 col2" >16818</td>
#       <td id="T_20479_row4_col3" class="data row4 col3" >2584</td>
#       <td id="T_20479_row4_col4" class="data row4 col4" >46</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row5_col0" class="data row5 col0" >R 300.14</td>
#       <td id="T_20479_row5_col1" class="data row5 col1" >Freni</td>
#       <td id="T_20479_row5_col2" class="data row5 col2" >73529</td>
#       <td id="T_20479_row5_col3" class="data row5 col3" >11344</td>
#       <td id="T_20479_row5_col4" class="data row5 col4" >153</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row6_col0" class="data row6 col0" >R 300.15</td>
#       <td id="T_20479_row6_col1" class="data row6 col1" >Forme d esercizio particolari</td>
#       <td id="T_20479_row6_col2" class="data row6 col2" >11542</td>
#       <td id="T_20479_row6_col3" class="data row6 col3" >1759</td>
#       <td id="T_20479_row6_col4" class="data row6 col4" >28</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row7_col0" class="data row7 col0" >R 300.2</td>
#       <td id="T_20479_row7_col1" class="data row7 col1" >Segnali</td>
#       <td id="T_20479_row7_col2" class="data row7 col2" >98071</td>
#       <td id="T_20479_row7_col3" class="data row7 col3" >14336</td>
#       <td id="T_20479_row7_col4" class="data row7 col4" >228</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row8_col0" class="data row8 col0" >R 300.3</td>
#       <td id="T_20479_row8_col1" class="data row8 col1" >Comunicazione disposizioni e trasmissione</td>
#       <td id="T_20479_row8_col2" class="data row8 col2" >46586</td>
#       <td id="T_20479_row8_col3" class="data row8 col3" >6748</td>
#       <td id="T_20479_row8_col4" class="data row8 col4" >97</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row9_col0" class="data row9 col0" >R 300.4</td>
#       <td id="T_20479_row9_col1" class="data row9 col1" >Movimenti di manovra</td>
#       <td id="T_20479_row9_col2" class="data row9 col2" >99079</td>
#       <td id="T_20479_row9_col3" class="data row9 col3" >15399</td>
#       <td id="T_20479_row9_col4" class="data row9 col4" >231</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row10_col0" class="data row10 col0" >R 300.5</td>
#       <td id="T_20479_row10_col1" class="data row10 col1" >Preparazione dei treni</td>
#       <td id="T_20479_row10_col2" class="data row10 col2" >49956</td>
#       <td id="T_20479_row10_col3" class="data row10 col3" >7900</td>
#       <td id="T_20479_row10_col4" class="data row10 col4" >99</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row11_col0" class="data row11 col0" >R 300.6</td>
#       <td id="T_20479_row11_col1" class="data row11 col1" >Corse dei treni</td>
#       <td id="T_20479_row11_col2" class="data row11 col2" >44126</td>
#       <td id="T_20479_row11_col3" class="data row11 col3" >6907</td>
#       <td id="T_20479_row11_col4" class="data row11 col4" >104</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row12_col0" class="data row12 col0" >R 300.7</td>
#       <td id="T_20479_row12_col1" class="data row12 col1" >Controllo della marcia dei treni</td>
#       <td id="T_20479_row12_col2" class="data row12 col2" >6406</td>
#       <td id="T_20479_row12_col3" class="data row12 col3" >940</td>
#       <td id="T_20479_row12_col4" class="data row12 col4" >16</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row13_col0" class="data row13 col0" >R 300.8</td>
#       <td id="T_20479_row13_col1" class="data row13 col1" >Sicurezza del lavoro</td>
#       <td id="T_20479_row13_col2" class="data row13 col2" >9992</td>
#       <td id="T_20479_row13_col3" class="data row13 col3" >1523</td>
#       <td id="T_20479_row13_col4" class="data row13 col4" >20</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row14_col0" class="data row14 col0" >R 300.9</td>
#       <td id="T_20479_row14_col1" class="data row14 col1" >Perturbazioni</td>
#       <td id="T_20479_row14_col2" class="data row14 col2" >71644</td>
#       <td id="T_20479_row14_col3" class="data row14 col3" >11048</td>
#       <td id="T_20479_row14_col4" class="data row14 col4" >162</td>
#     </tr>
#     <tr>
#       <td id="T_20479_row15_col0" class="data row15 col0" >TOTAL</td>
#       <td id="T_20479_row15_col1" class="data row15 col1" ></td>
#       <td id="T_20479_row15_col2" class="data row15 col2" >624765</td>
#       <td id="T_20479_row15_col3" class="data row15 col3" >94902</td>
#       <td id="T_20479_row15_col4" class="data row15 col4" >1398</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Combined summary across all three languages
combined_rows = []
for lang in LANGUAGES:
    for doc in docs_by_lang[lang]:
        doc_chunks = [c for c in chunks_by_lang[lang]
                      if c["source_file"] == doc["source_file"]]
        combined_rows.append({
            "Language":   lang.upper(),
            "Regulation": doc["regulation_number"],
            "Characters": len(doc["text"]),
            "Words":      len(doc["text"].split()),
            "Chunks":     len(doc_chunks),
        })

df_combined = pd.DataFrame(combined_rows)
display(df_combined.groupby("Language")[["Characters", "Words", "Chunks"]]
        .sum().rename(columns=str.capitalize))

# Grouped bar chart: document length per regulation, all three languages side by side
regs   = sorted(df_combined["Regulation"].unique())
x      = np.arange(len(regs))
width  = 0.25
colors = {"DE": "steelblue", "FR": "darkorange", "IT": "seagreen"}

fig, ax = plt.subplots(figsize=(14, 5))
for i, lang in enumerate(["DE", "FR", "IT"]):
    subset = df_combined[df_combined["Language"] == lang].set_index("Regulation")
    values = [subset.loc[r, "Characters"] if r in subset.index else 0 for r in regs]
    ax.bar(x + (i - 1) * width, values, width, label=lang, color=colors[lang])

ax.set_xticks(x)
ax.set_xticklabels(regs, rotation=45, ha="right", fontsize=8)
ax.set_ylabel("Characters")
ax.set_title("Document length per regulation — all languages")
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f"{int(v):,}"))
ax.legend()
plt.tight_layout()
plt.show()
# Out:
#           Characters   Words  Chunks
# Language
# DE            580833   74753    1351
# FR            647969  101856    1469
# IT            624765   94902    1398

# %% [markdown]
# ## Section 2 — Chunk Size Distribution

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
for ax, lang in zip(axes, LANGUAGES):
    sizes = [len(c["text"]) for c in chunks_by_lang[lang]]
    ax.hist(sizes, bins=40, color="steelblue", edgecolor="white")
    ax.axvline(CHUNK_MIN_CHARS, color="orange", linestyle="--",
               label=f"MIN={CHUNK_MIN_CHARS}")
    ax.axvline(CHUNK_MAX_CHARS, color="red",    linestyle="--",
               label=f"MAX={CHUNK_MAX_CHARS}")
    ax.set_title(f"Chunk sizes — {lang.upper()}")
    ax.set_xlabel("Characters")
    ax.legend(fontsize=8)
axes[0].set_ylabel("Count")
plt.suptitle("Corpus-wide chunk character length distribution", y=1.02)
plt.tight_layout()
plt.show()

# %%
# Per-document boxplot within each language
for lang in LANGUAGES:
    reg_sizes = {}
    for c in chunks_by_lang[lang]:
        reg = c["regulation_number"]
        reg_sizes.setdefault(reg, []).append(len(c["text"]))

    regs  = sorted(reg_sizes.keys())
    data  = [reg_sizes[r] for r in regs]

    fig, ax = plt.subplots(figsize=(12, 4))
    ax.boxplot(data, labels=regs, vert=True)
    ax.axhline(CHUNK_MIN_CHARS, color="orange", linestyle="--", alpha=0.7)
    ax.axhline(CHUNK_MAX_CHARS, color="red",    linestyle="--", alpha=0.7)
    ax.set_title(f"Chunk size per regulation — {lang.upper()}")
    ax.set_ylabel("Characters")
    ax.set_xticklabels(regs, rotation=45, ha="right", fontsize=7)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\niw\AppData\Local\Temp\ipykernel_11356\3737308966.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=regs, vert=True)
# C:\Users\niw\AppData\Local\Temp\ipykernel_11356\3737308966.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=regs, vert=True)
# C:\Users\niw\AppData\Local\Temp\ipykernel_11356\3737308966.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=regs, vert=True)

# %% [markdown]
# ## Section 3 — Sentence Length Distribution

# %%
_SENT_RE = re.compile(r"[.!?]+\s+")

def sentence_lengths(text: str):
    """Return (word_counts, char_counts) for each sentence with > 1 word."""
    sentences = _SENT_RE.split(text)
    sentences = [s.strip() for s in sentences if len(s.split()) > 1]
    word_counts = [len(s.split()) for s in sentences]
    char_counts = [len(s) for s in sentences]
    return word_counts, char_counts

# Collect per language
sent_data = {}
for lang in LANGUAGES:
    all_text = " ".join(c["text"] for c in chunks_by_lang[lang])
    wc, cc   = sentence_lengths(all_text)
    sent_data[lang] = {"words": wc, "chars": cc}

# 2-row plot: top = word count, bottom = character count
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

for col, lang in enumerate(LANGUAGES):
    wc = sent_data[lang]["words"]
    cc = sent_data[lang]["chars"]

    # Word count
    ax = axes[0][col]
    med_w = np.median(wc)
    ax.hist(wc, bins=50, range=(0, 80), color="teal", edgecolor="white")
    ax.axvline(med_w, color="red", linestyle="--", label=f"median={med_w:.0f}")
    ax.set_title(f"Words/sentence — {lang.upper()}")
    ax.set_xlabel("Words")
    ax.legend(fontsize=8)

    # Character count
    ax = axes[1][col]
    med_c = np.median(cc)
    ax.hist(cc, bins=50, range=(0, 500), color="steelblue", edgecolor="white")
    ax.axvline(med_c, color="red", linestyle="--", label=f"median={med_c:.0f}")
    ax.set_title(f"Chars/sentence — {lang.upper()}")
    ax.set_xlabel("Characters")
    ax.legend(fontsize=8)

axes[0][0].set_ylabel("Count")
axes[1][0].set_ylabel("Count")
plt.suptitle("Sentence length distribution — words (top) and characters (bottom)", y=1.01)
plt.tight_layout()
plt.show()

# Summary table
print(f"{'Lang':<6} {'Med words':>10} {'Mean words':>11} {'Med chars':>10} {'Mean chars':>11} {'Sentences':>10}")
print("-" * 60)
for lang in LANGUAGES:
    wc = sent_data[lang]["words"]
    cc = sent_data[lang]["chars"]
    print(f"{lang.upper():<6} {np.median(wc):>10.1f} {np.mean(wc):>11.1f} "
          f"{np.median(cc):>10.1f} {np.mean(cc):>11.1f} {len(wc):>10,}")
# Out:
# Lang    Med words  Mean words  Med chars  Mean chars  Sentences
# ------------------------------------------------------------
# DE           16.0        20.5      119.0       156.8      3,822
# FR           22.0        29.1      138.0       182.0      3,700
# IT           21.0        27.8      135.0       180.1      3,605

# %% [markdown]
# ## Section 4 — Vocabulary & Automatic Term Discovery

# %%
vocab_stats = {}

for lang in LANGUAGES:
    all_text  = " ".join(c["text"] for c in chunks_by_lang[lang])
    tokens    = tokenize(all_text)
    cw        = content_words(tokens, lang)
    freq      = Counter(cw)
    top40     = freq.most_common(40)
    vocab_stats[lang] = {"freq": freq, "types": len(set(cw)), "tokens": len(cw)}

    words, counts = zip(*top40)
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.barh(list(reversed(words)), list(reversed(counts)), color="steelblue")
    ax.set_title(f"Top 40 content words — {lang.upper()}")
    ax.set_xlabel("Frequency")
    plt.tight_layout()
    plt.show()

    print(f"  {lang.upper()}: {vocab_stats[lang]['types']:,} unique content word types")
# Out:
#   DE: 6,786 unique content word types
#   FR: 4,648 unique content word types
#   IT: 4,927 unique content word types

# %%
# Grouped bar: top-20 terms per language side by side
top_n = 20
top_terms_per_lang = {
    lang: [w for w, _ in vocab_stats[lang]["freq"].most_common(top_n)]
    for lang in LANGUAGES
}
all_top = list(dict.fromkeys(
    w for lang in LANGUAGES for w in top_terms_per_lang[lang]
))

matrix = np.array([
    [vocab_stats[lang]["freq"].get(w, 0) for w in all_top]
    for lang in LANGUAGES
])

# Normalise per language for comparability
matrix_norm = matrix / matrix.max(axis=1, keepdims=True)

fig, ax = plt.subplots(figsize=(14, 5))
im = ax.imshow(matrix_norm, aspect="auto", cmap="YlOrRd")
ax.set_yticks(range(len(LANGUAGES)))
ax.set_yticklabels([l.upper() for l in LANGUAGES])
ax.set_xticks(range(len(all_top)))
ax.set_xticklabels(all_top, rotation=60, ha="right", fontsize=8)
plt.colorbar(im, ax=ax, label="Normalised frequency")
ax.set_title(f"Heat-map of top content words per language (top {top_n} each)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Section 5 — Terminology Density

# %%
density_rows = []
for lang in LANGUAGES:
    for doc in docs_by_lang[lang]:
        tokens = tokenize(doc["text"])
        if not tokens:
            continue
        ttr      = len(set(tokens)) / len(tokens)
        avg_wlen = np.mean([len(t) for t in tokens])
        density_rows.append({
            "language":         lang.upper(),
            "regulation":       doc["regulation_number"],
            "ttr":              ttr,
            "avg_word_length":  avg_wlen,
            "token_count":      len(tokens),
        })

df_density = pd.DataFrame(density_rows)
display(df_density.sort_values(["language", "ttr"], ascending=[True, False])
        .style.format({"ttr": "{:.3f}", "avg_word_length": "{:.2f}"}))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, metric, title in [
    (axes[0], "ttr",             "Type-Token Ratio (TTR) per document"),
    (axes[1], "avg_word_length", "Avg token length (proxy for compound words)"),
]:
    for lang in LANGUAGES:
        subset = df_density[df_density["language"] == lang.upper()]
        ax.scatter(subset["regulation"], subset[metric], label=lang.upper(), s=60)
    ax.set_title(title)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=7)
    ax.legend()
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_719d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_719d8_level0_col0" class="col_heading level0 col0" >language</th>
#       <th id="T_719d8_level0_col1" class="col_heading level0 col1" >regulation</th>
#       <th id="T_719d8_level0_col2" class="col_heading level0 col2" >ttr</th>
#       <th id="T_719d8_level0_col3" class="col_heading level0 col3" >avg_word_length</th>
#       <th id="T_719d8_level0_col4" class="col_heading level0 col4" >token_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_719d8_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_719d8_row0_col0" class="data row0 col0" >DE</td>
#       <td id="T_719d8_row0_col1" class="data row0 col1" >R 300.11</td>
#       <td id="T_719d8_row0_col2" class="data row0 col2" >0.612</td>
#       <td id="T_719d8_row0_col3" class="data row0 col3" >9.29</td>
#       <td id="T_719d8_row0_col4" class="data row0 col4" >379</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_719d8_row1_col0" class="data row1 col0" >DE</td>
#       <td id="T_719d8_row1_col1" class="data row1 col1" >R 300.7</td>
#       <td id="T_719d8_row1_col2" class="data row1 col2" >0.579</td>
#       <td id="T_719d8_row1_col3" class="data row1 col3" >9.21</td>
#       <td id="T_719d8_row1_col4" class="data row1 col4" >456</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_719d8_row2_col0" class="data row2 col0" >DE</td>
#       <td id="T_719d8_row2_col1" class="data row2 col1" >R 300.8</td>
#       <td id="T_719d8_row2_col2" class="data row2 col2" >0.558</td>
#       <td id="T_719d8_row2_col3" class="data row2 col3" >8.80</td>
#       <td id="T_719d8_row2_col4" class="data row2 col4" >745</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_719d8_row3_col0" class="data row3 col0" >DE</td>
#       <td id="T_719d8_row3_col1" class="data row3 col1" >R 300.13</td>
#       <td id="T_719d8_row3_col2" class="data row3 col2" >0.535</td>
#       <td id="T_719d8_row3_col3" class="data row3 col3" >8.93</td>
#       <td id="T_719d8_row3_col4" class="data row3 col4" >1227</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_719d8_row4_col0" class="data row4 col0" >DE</td>
#       <td id="T_719d8_row4_col1" class="data row4 col1" >R 300.10</td>
#       <td id="T_719d8_row4_col2" class="data row4 col2" >0.521</td>
#       <td id="T_719d8_row4_col3" class="data row4 col3" >8.44</td>
#       <td id="T_719d8_row4_col4" class="data row4 col4" >328</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_719d8_row5_col0" class="data row5 col0" >DE</td>
#       <td id="T_719d8_row5_col1" class="data row5 col1" >R 300.1</td>
#       <td id="T_719d8_row5_col2" class="data row5 col2" >0.416</td>
#       <td id="T_719d8_row5_col3" class="data row5 col3" >9.21</td>
#       <td id="T_719d8_row5_col4" class="data row5 col4" >3566</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row6" class="row_heading level0 row6" >14</th>
#       <td id="T_719d8_row6_col0" class="data row6 col0" >DE</td>
#       <td id="T_719d8_row6_col1" class="data row6 col1" >R 300.15</td>
#       <td id="T_719d8_row6_col2" class="data row6 col2" >0.395</td>
#       <td id="T_719d8_row6_col3" class="data row6 col3" >8.54</td>
#       <td id="T_719d8_row6_col4" class="data row6 col4" >892</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_719d8_row7_col0" class="data row7 col0" >DE</td>
#       <td id="T_719d8_row7_col1" class="data row7 col1" >R 300.3</td>
#       <td id="T_719d8_row7_col2" class="data row7 col2" >0.378</td>
#       <td id="T_719d8_row7_col3" class="data row7 col3" >8.84</td>
#       <td id="T_719d8_row7_col4" class="data row7 col4" >3417</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_719d8_row8_col0" class="data row8 col0" >DE</td>
#       <td id="T_719d8_row8_col1" class="data row8 col1" >R 300.14</td>
#       <td id="T_719d8_row8_col2" class="data row8 col2" >0.317</td>
#       <td id="T_719d8_row8_col3" class="data row8 col3" >8.88</td>
#       <td id="T_719d8_row8_col4" class="data row8 col4" >5323</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_719d8_row9_col0" class="data row9 col0" >DE</td>
#       <td id="T_719d8_row9_col1" class="data row9 col1" >R 300.5</td>
#       <td id="T_719d8_row9_col2" class="data row9 col2" >0.298</td>
#       <td id="T_719d8_row9_col3" class="data row9 col3" >8.85</td>
#       <td id="T_719d8_row9_col4" class="data row9 col4" >3550</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_719d8_row10_col0" class="data row10 col0" >DE</td>
#       <td id="T_719d8_row10_col1" class="data row10 col1" >R 300.12</td>
#       <td id="T_719d8_row10_col2" class="data row10 col2" >0.295</td>
#       <td id="T_719d8_row10_col3" class="data row10 col3" >8.85</td>
#       <td id="T_719d8_row10_col4" class="data row10 col4" >2867</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row11" class="row_heading level0 row11" >5</th>
#       <td id="T_719d8_row11_col0" class="data row11 col0" >DE</td>
#       <td id="T_719d8_row11_col1" class="data row11 col1" >R 300.6</td>
#       <td id="T_719d8_row11_col2" class="data row11 col2" >0.281</td>
#       <td id="T_719d8_row11_col3" class="data row11 col3" >8.93</td>
#       <td id="T_719d8_row11_col4" class="data row11 col4" >3208</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row12" class="row_heading level0 row12" >3</th>
#       <td id="T_719d8_row12_col0" class="data row12 col0" >DE</td>
#       <td id="T_719d8_row12_col1" class="data row12 col1" >R 300.4</td>
#       <td id="T_719d8_row12_col2" class="data row12 col2" >0.243</td>
#       <td id="T_719d8_row12_col3" class="data row12 col3" >8.55</td>
#       <td id="T_719d8_row12_col4" class="data row12 col4" >7540</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row13" class="row_heading level0 row13" >8</th>
#       <td id="T_719d8_row13_col0" class="data row13 col0" >DE</td>
#       <td id="T_719d8_row13_col1" class="data row13 col1" >R 300.9</td>
#       <td id="T_719d8_row13_col2" class="data row13 col2" >0.232</td>
#       <td id="T_719d8_row13_col3" class="data row13 col3" >8.52</td>
#       <td id="T_719d8_row13_col4" class="data row13 col4" >5426</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row14" class="row_heading level0 row14" >1</th>
#       <td id="T_719d8_row14_col0" class="data row14 col0" >DE</td>
#       <td id="T_719d8_row14_col1" class="data row14 col1" >R 300.2</td>
#       <td id="T_719d8_row14_col2" class="data row14 col2" >0.220</td>
#       <td id="T_719d8_row14_col3" class="data row14 col3" >8.65</td>
#       <td id="T_719d8_row14_col4" class="data row14 col4" >7208</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row15" class="row_heading level0 row15" >25</th>
#       <td id="T_719d8_row15_col0" class="data row15 col0" >FR</td>
#       <td id="T_719d8_row15_col1" class="data row15 col1" >R 300.11</td>
#       <td id="T_719d8_row15_col2" class="data row15 col2" >0.482</td>
#       <td id="T_719d8_row15_col3" class="data row15 col3" >7.93</td>
#       <td id="T_719d8_row15_col4" class="data row15 col4" >481</td>
#     </tr>
#     <tr>
#       <th id="T_719d8_level0_row16" class="row_heading level0 row16" >22</th>
#       <td id="T_719d8_row16_col0" class="data row16 col0" >FR</td>
#       <td id="T_719d8_row16_col1" class="data row16 col1" >R 300.8</td>
#       <td id="T_719d8_row16_col2" class="data row16 col2" >0.482</td>
#       <td id="T_719d8_row16_col3" class="data row16 col3" >7.34</td>
#       <td id="T_719d8_row16_col4" class="data row16 col4" >888</td>
#     </tr>
#     <tr>
#       <t
# C:\Users\niw\AppData\Local\Temp\ipykernel_11356\616202476.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=7)
# C:\Users\niw\AppData\Local\Temp\ipykernel_11356\616202476.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=7)

# %% [markdown]
# ## Section 6 — TF-IDF Signatures per Document & Language

# %%
TOP_TFIDF = 8

for lang in LANGUAGES:
    lang_chunks = chunks_by_lang[lang]
    texts       = [c["text"] for c in lang_chunks]

    stops_list  = list(STOPWORDS[lang])

    vect = TfidfVectorizer(
        token_pattern=r"(?u)\b[a-z\u00c0-\u024f]{4,}\b",
        lowercase=True,
        min_df=2,
        sublinear_tf=True,
        stop_words=stops_list,
    )
    X            = vect.fit_transform(texts)
    feature_names = np.array(vect.get_feature_names_out())

    # Group chunks by regulation
    regs = sorted(set(c["regulation_number"] for c in lang_chunks))
    rows = []
    for reg in regs:
        idxs    = [i for i, c in enumerate(lang_chunks)
                   if c["regulation_number"] == reg]
        doc_vec = np.asarray(X[idxs].mean(axis=0)).flatten()
        top_idx = doc_vec.argsort()[-TOP_TFIDF:][::-1]
        rows.append({
            "Regulation": reg,
            "Top TF-IDF terms": ", ".join(feature_names[top_idx]),
        })

    df_tfidf = pd.DataFrame(rows)
    print(f"\n{'='*60}")
    print(f"  TF-IDF signatures — {lang.upper()}")
    print(f"{'='*60}")
    display(df_tfidf.style.hide(axis="index"))
# Out:
# ============================================================
#   TF-IDF signatures — DE
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_0ef3a">
#   <thead>
#     <tr>
#       <th id="T_0ef3a_level0_col0" class="col_heading level0 col0" >Regulation</th>
#       <th id="T_0ef3a_level0_col1" class="col_heading level0 col1" >Top TF-IDF terms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0ef3a_row0_col0" class="data row0 col0" >R 300.1</td>
#       <td id="T_0ef3a_row0_col1" class="data row0 col1" >teil, trambetrieb, fahrten, strecke, betriebsvorschriften, funktionen, bahnbetrieb, geltungsbereich</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row1_col0" class="data row1 col0" >R 300.10</td>
#       <td id="T_0ef3a_row1_col1" class="data row1 col1" >kategorie, formulare, befehle, formularen, verwenden, enthalten, entsprechende, formular</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row2_col0" class="data row2 col0" >R 300.11</td>
#       <td id="T_0ef3a_row2_col1" class="data row2 col1" >fahrleitungen, ausgeschaltet, ipea, erden, berechtigt, spea, schaltbefehle, fahrleitung</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row3_col0" class="data row3 col0" >R 300.12</td>
#       <td id="T_0ef3a_row3_col1" class="data row3 col1" >sicherheitsmassnahmen, arbeitsstelle, arbeiten, arbeitsstellen, sidi, personal, gleisbereich, siwä</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row4_col0" class="data row4 col0" >R 300.13</td>
#       <td id="T_0ef3a_row4_col1" class="data row4 col1" >während, fahrt, führerstand, ausbildung, arbeit, mitverantwortlich, dampflokomotiven, dampflokomotive</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row5_col0" class="data row5 col0" >R 300.14</td>
#       <td id="T_0ef3a_row5_col1" class="data row5 col1" >bremse, hauptleitung, bremsen, bremszylinder, lösen, druckluft, druck, automatische</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row6_col0" class="data row6 col0" >R 300.15</td>
#       <td id="T_0ef3a_row6_col1" class="data row6 col1" >kreuzung, fahrpersonal, block, teilzüge, protokollpflichtig, strecke, kreuzungen, ohne</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row7_col0" class="data row7 col0" >R 300.2</td>
#       <td id="T_0ef3a_row7_col1" class="data row7 col1" >bedeutung, begriff, signal, signalen, beziehung, anderen, halt, signale</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row8_col0" class="data row8 col0" >R 300.3</td>
#       <td id="T_0ef3a_row8_col1" class="data row8 col1" >antworten, übermittlung, verstanden, nachricht, verbindung, nachrichten, richtig, empfänger</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row9_col0" class="data row9 col0" >R 300.4</td>
#       <td id="T_0ef3a_row9_col1" class="data row9 col1" >rangierbewegung, rangierbewegungen, fahrzeuge, zustimmung, wagen, fahrweg, gesperrten, gleise</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row10_col0" class="data row10 col0" >R 300.5</td>
#       <td id="T_0ef3a_row10_col1" class="data row10 col1" >wagen, fahrzeuge, züge, triebfahrzeuge, bremsgewicht, angerechnet, betriebsvorschriften, bremsprobe</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row11_col0" class="data row11 col0" >R 300.6</td>
#       <td id="T_0ef3a_row11_col1" class="data row11 col1" >fahrt, halt, geschwindigkeitsschwelle, zustimmung, züge, gleis, halteort, anzuhalten</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row12_col0" class="data row12 col0" >R 300.7</td>
#       <td id="T_0ef3a_row12_col1" class="data row12 col1" >überwachung, zugbeeinflussung, zwangsbremsung, funktionen, bremskurve, funktion, streckendaten, infrastruktur</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row13_col0" class="data row13 col0" >R 300.8</td>
#       <td id="T_0ef3a_row13_col1" class="data row13 col1" >gefahren, mitarbeitenden, arbeiten, gleisbereich, fahrzeugen, insbesondere, zugsammelschiene, verhalten</td>
#     </tr>
#     <tr>
#       <td id="T_0ef3a_row14_col0" class="data row14 col0" >R 300.9</td>
#       <td id="T_0ef3a_row14_col1" class="data row14 col1" >fahrt, weiche, befahren, gestörten, technischen, verständigen, zustimmung, vorgehen</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   TF-IDF signatures — FR
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_197df">
#   <thead>
#     <tr>
#       <th id="T_197df_level0_col0" class="col_heading level0 col0" >Regulation</th>
#       <th id="T_197df_level0_col1" class="col_heading level0 col1" >Top TF-IDF terms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_197df_row0_col0" class="data row0 col0" >R 300.1</td>
#       <td id="T_197df_row0_col1" class="data row0 col1" >exploitation, circulation, trains, voies, voie, tramways, ferroviaire, application</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row1_col0" class="data row1 col0" >R 300.10</td>
#       <td id="T_197df_row1_col1" class="data row1 col1" >formulaires, ordres, catégorie, formulaire, case, contenu, comprennent, textes</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row2_col0" class="data row2 col0" >R 300.11</td>
#       <td id="T_197df_row2_col1" class="data row2 col1" >enclenchement, déclenchement, contact, lignes, terre, ordres, interrupteurs, piie</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row3_col0" class="data row3 col0" >R 300.12</td>
#       <td id="T_197df_row3_col1" class="data row3 col1" >sécurité, mesures, alarme, chantier, travaux, personnel, chantiers, voie</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row4_col0" class="data row4 col0" >R 300.13</td>
#       <td id="T_197df_row4_col1" class="data row4 col1" >vapeur, conduite, connaissances, pendant, cabine, locomotive, marche, personne</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row5_col0" class="data row5 col0" >R 300.14</td>
#       <td id="T_197df_row5_col1" class="data row5 col1" >frein, pression, générale, conduite, freins, serrage, cylindre, comprimé</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row6_col0" class="data row6 col0" >R 300.15</td>
#       <td id="T_197df_row6_col1" class="data row6 col1" >croisement, train, ordre, roulant, parties, gare, block, inverse</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row7_col0" class="data row7 col0" >R 300.2</td>
#       <td id="T_197df_row7_col1" class="data row7 col1" >signal, image, signification, signaux, vitesse, voie, relation, arrêt</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row8_col0" class="data row8 col0" >R 300.3</td>
#       <td id="T_197df_row8_col1" class="data row8 col1" >transmission, liaison, message, appel, messages, répondez, communication, ordre</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row9_col0" class="data row9 col0" >R 300.4</td>
#       <td id="T_197df_row9_col1" class="data row9 col1" >manœuvre, véhicules, cman, voie, mouvements, mouvement, assentiment, arrêt</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row10_col0" class="data row10 col0" >R 300.5</td>
#       <td id="T_197df_row10_col1" class="data row10 col1" >frein, train, véhicules, poids, freinage, trains, prescriptions, moteurs</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row11_col0" class="data row11 col0" >R 300.6</td>
#       <td id="T_197df_row11_col1" class="data row11 col1" >vitesse, signal, voie, train, arrêt, circuler, signaux, trains</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row12_col0" class="data row12 col0" >R 300.7</td>
#       <td id="T_197df_row12_col1" class="data row12 col1" >surveillance, contrôle, fonctions, système, trains, marche, vitesse, fonction</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row13_col0" class="data row13 col0" >R 300.8</td>
#       <td id="T_197df_row13_col1" class="data row13 col1" >dangers, collaborateurs, voies, travaux, abords, sécurité, comportement, contact</td>
#     </tr>
#     <tr>
#       <td id="T_197df_row14_col0" class="data row14 col0" >R 300.9</td>
#       <td id="T_197df_row14_col1" class="data row14 col1" >dérangement, marche, aiguille, signal, convoi, installation, train, endroit</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   TF-IDF signatures — IT
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_cc20a">
#   <thead>
#     <tr>
#       <th id="T_cc20a_level0_col0" class="col_heading level0 col0" >Regulation</th>
#       <th id="T_cc20a_level0_col1" class="col_heading level0 col1" >Top TF-IDF terms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cc20a_row0_col0" class="data row0 col0" >R 300.1</td>
#       <td id="T_cc20a_row0_col1" class="data row0 col1" >esercizio, tram, binari, corse, tratta, prescrizioni, validità, manovra</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row1_col0" class="data row1 col0" >R 300.10</td>
#       <td id="T_cc20a_row1_col1" class="data row1 col1" >formulari, ordini, categoria, contenuto, singoli, campi, contengono, vincolanti</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row2_col0" class="data row2 col0" >R 300.11</td>
#       <td id="T_cc20a_row2_col1" class="data row2 col1" >commutazione, contatto, terra, linee, ordini, messa, interruttori, disinserimento</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row3_col0" class="data row3 col0" >R 300.12</td>
#       <td id="T_cc20a_row3_col1" class="data row3 col1" >lavori, misure, sicurezza, area, allarme, lavoro, personale, binari</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row4_col0" class="data row4 col0" >R 300.13</td>
#       <td id="T_cc20a_row4_col1" class="data row4 col1" >vapore, guida, corsa, cabina, conoscenze, aiuto, servizio, motore</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row5_col0" class="data row5 col0" >R 300.14</td>
#       <td id="T_cc20a_row5_col1" class="data row5 col1" >freno, pressione, freni, aria, condotta, frenatura, principale, cilindro</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row6_col0" class="data row6 col0" >R 300.15</td>
#       <td id="T_cc20a_row6_col1" class="data row6 col1" >incrocio, treno, viaggiante, protocollo, sezioni, stazione, blocco, tratta</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row7_col0" class="data row7 col0" >R 300.2</td>
#       <td id="T_cc20a_row7_col1" class="data row7 col1" >segnale, significato, termine, segnali, fermata, velocità, relazione, tavola</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row8_col0" class="data row8 col0" >R 300.3</td>
#       <td id="T_cc20a_row8_col1" class="data row8 col1" >trasmissione, chiamata, rispondere, collegamento, comunicazione, capito, ordine, messaggio</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row9_col0" class="data row9 col0" >R 300.4</td>
#       <td id="T_cc20a_row9_col1" class="data row9 col1" >manovra, veicoli, cman, movimento, movimenti, binari, binario, itinerario</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row10_col0" class="data row10 col0" >R 300.5</td>
#       <td id="T_cc20a_row10_col1" class="data row10 col1" >freno, peso, veicoli, treno, freni, frenatura, treni, motore</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row11_col0" class="data row11 col0" >R 300.6</td>
#       <td id="T_cc20a_row11_col1" class="data row11 col1" >velocità, fermata, segnale, treno, binario, treni, soglia, segnali</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row12_col0" class="data row12 col0" >R 300.7</td>
#       <td id="T_cc20a_row12_col1" class="data row12 col1" >controllo, sorveglianza, marcia, sistema, frenatura, funzioni, funzione, treni</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row13_col0" class="data row13 col0" >R 300.8</td>
#       <td id="T_cc20a_row13_col1" class="data row13 col1" >pericoli, lavori, collaboratori, binari, veicoli, elettrica, contatto, tensione</td>
#     </tr>
#     <tr>
#       <td id="T_cc20a_row14_col0" class="data row14 col0" >R 300.9</td>
#       <td id="T_cc20a_row14_col1" class="data row14 col1" >corsa, cmov, segnale, scambio, proseguire, treno, possibile, posizione</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Section 7 — Gini Score per Document
#
# The Gini coefficient measures how concentrated the vocabulary is: a score near 1 means a few terms dominate (highly specialized), near 0 means uniform usage. Higher Gini documents tend to retrieve more precisely because their key terms are distinctive — useful context for tuning retrieval parameters.

# %%
def gini(freqs):
    """Gini coefficient of a frequency distribution (0 = uniform, 1 = maximally concentrated)."""
    arr = np.sort(np.array(freqs, dtype=float))
    n   = len(arr)
    if n == 0 or arr.sum() == 0:
        return 0.0
    idx = np.arange(1, n + 1)
    return (2 * np.sum(idx * arr) / (n * arr.sum())) - (n + 1) / n


gini_rows = []
for lang in LANGUAGES:
    for doc in docs_by_lang[lang]:
        tokens = tokenize(doc["text"])
        cw     = content_words(tokens, lang)
        if not cw:
            continue
        freq  = Counter(cw)
        score = gini(list(freq.values()))
        gini_rows.append({
            "language":      lang.upper(),
            "regulation":    doc["regulation_number"],
            "title":         doc["document_title"],
            "gini":          score,
            "unique_types":  len(freq),
            "total_tokens":  len(cw),
        })

df_gini = pd.DataFrame(gini_rows).sort_values(["language", "gini"], ascending=[True, False])
display(df_gini.style
        .format({"gini": "{:.4f}"})
        .background_gradient(subset=["gini"], cmap="YlOrRd")
        .hide(axis="index"))

# Per-language bar charts
fig, axes = plt.subplots(1, 3, figsize=(16, 5), sharey=True)
for ax, lang in zip(axes, LANGUAGES):
    sub  = df_gini[df_gini["language"] == lang.upper()].sort_values("gini")
    norm = sub["gini"] / sub["gini"].max() if sub["gini"].max() > 0 else sub["gini"]
    bars = ax.barh(sub["regulation"], sub["gini"],
                   color=plt.cm.YlOrRd(norm))
    ax.set_title(f"Gini — {lang.upper()}")
    ax.set_xlabel("Gini coefficient")
    ax.set_xlim(0, 1)
    for bar, val in zip(bars, sub["gini"]):
        ax.text(bar.get_width() + 0.005, bar.get_y() + bar.get_height() / 2,
                f"{val:.3f}", va="center", fontsize=7)
axes[0].set_ylabel("Regulation")
plt.suptitle(
    "Gini coefficient of content-word frequency per document\n"
    "(higher = vocabulary concentrated in fewer terms → more domain-specific signal)",
    y=1.02,
)
plt.tight_layout()
plt.show()

# Cross-language line comparison
fig, ax = plt.subplots(figsize=(12, 4))
for lang in LANGUAGES:
    sub = df_gini[df_gini["language"] == lang.upper()].sort_values("regulation")
    ax.plot(sub["regulation"], sub["gini"], marker="o", label=lang.upper())
ax.set_title("Gini score per regulation across languages")
ax.set_ylabel("Gini coefficient")
ax.set_ylim(0, 1)
ax.tick_params(axis="x", rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

print("\nSummary — mean Gini per language:")
print(df_gini.groupby("language")["gini"].agg(["mean", "min", "max"]).round(4))
# Out:
# <style type="text/css">
# #T_0888e_row0_col3, #T_0888e_row19_col3 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
# }
# #T_0888e_row1_col3 {
#   background-color: #fb4b29;
#   color: #f1f1f1;
# }
# #T_0888e_row2_col3 {
#   background-color: #fc612f;
#   color: #f1f1f1;
# }
# #T_0888e_row3_col3 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_0888e_row4_col3 {
#   background-color: #fd7435;
#   color: #f1f1f1;
# }
# #T_0888e_row5_col3, #T_0888e_row6_col3 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_0888e_row7_col3 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_0888e_row8_col3 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_0888e_row9_col3, #T_0888e_row25_col3 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_0888e_row10_col3 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_0888e_row11_col3 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_0888e_row12_col3 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_0888e_row13_col3 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_0888e_row14_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0888e_row15_col3, #T_0888e_row30_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0888e_row16_col3 {
#   background-color: #b70026;
#   color: #f1f1f1;
# }
# #T_0888e_row17_col3 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# #T_0888e_row18_col3 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_0888e_row20_col3, #T_0888e_row34_col3 {
#   background-color: #d6111f;
#   color: #f1f1f1;
# }
# #T_0888e_row21_col3 {
#   background-color: #dc151e;
#   color: #f1f1f1;
# }
# #T_0888e_row22_col3 {
#   background-color: #ee3122;
#   color: #f1f1f1;
# }
# #T_0888e_row23_col3, #T_0888e_row38_col3 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# #T_0888e_row24_col3 {
#   background-color: #fc552c;
#   color: #f1f1f1;
# }
# #T_0888e_row26_col3 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_0888e_row27_col3 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_0888e_row28_col3 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_0888e_row29_col3 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_0888e_row31_col3 {
#   background-color: #b20026;
#   color: #f1f1f1;
# }
# #T_0888e_row32_col3 {
#   background-color: #c20325;
#   color: #f1f1f1;
# }
# #T_0888e_row33_col3 {
#   background-color: #c80723;
#   color: #f1f1f1;
# }
# #T_0888e_row35_col3 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_0888e_row36_col3 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_0888e_row37_col3 {
#   background-color: #f13624;
#   color: #f1f1f1;
# }
# #T_0888e_row39_col3 {
#   background-color: #fc6330;
#   color: #f1f1f1;
# }
# #T_0888e_row40_col3 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_0888e_row41_col3 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_0888e_row42_col3 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_0888e_row43_col3 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_0888e_row44_col3 {
#   background-color: #fede82;
#   color: #000000;
# }
# </style>
# <table id="T_0888e">
#   <thead>
#     <tr>
#       <th id="T_0888e_level0_col0" class="col_heading level0 col0" >language</th>
#       <th id="T_0888e_level0_col1" class="col_heading level0 col1" >regulation</th>
#       <th id="T_0888e_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_0888e_level0_col3" class="col_heading level0 col3" >gini</th>
#       <th id="T_0888e_level0_col4" class="col_heading level0 col4" >unique_types</th>
#       <th id="T_0888e_level0_col5" class="col_heading level0 col5" >total_tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0888e_row0_col0" class="data row0 col0" >DE</td>
#       <td id="T_0888e_row0_col1" class="data row0 col1" >R 300.2</td>
#       <td id="T_0888e_row0_col2" class="data row0 col2" >Signale</td>
#       <td id="T_0888e_row0_col3" class="data row0 col3" >0.6153</td>
#       <td id="T_0888e_row0_col4" class="data row0 col4" >1542</td>
#       <td id="T_0888e_row0_col5" class="data row0 col5" >6267</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row1_col0" class="data row1 col0" >DE</td>
#       <td id="T_0888e_row1_col1" class="data row1 col1" >R 300.4</td>
#       <td id="T_0888e_row1_col2" class="data row1 col2" >Rangierbewegungen</td>
#       <td id="T_0888e_row1_col3" class="data row1 col3" >0.5360</td>
#       <td id="T_0888e_row1_col4" class="data row1 col4" >1780</td>
#       <td id="T_0888e_row1_col5" class="data row1 col5" >5910</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row2_col0" class="data row2 col0" >DE</td>
#       <td id="T_0888e_row2_col1" class="data row2 col1" >R 300.9</td>
#       <td id="T_0888e_row2_col2" class="data row2 col2" >Stoerungen</td>
#       <td id="T_0888e_row2_col3" class="data row2 col3" >0.5172</td>
#       <td id="T_0888e_row2_col4" class="data row2 col4" >1208</td>
#       <td id="T_0888e_row2_col5" class="data row2 col5" >4244</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row3_col0" class="data row3 col0" >DE</td>
#       <td id="T_0888e_row3_col1" class="data row3 col1" >R 300.12</td>
#       <td id="T_0888e_row3_col2" class="data row3 col2" >Arbeiten im Gleisbereich</td>
#       <td id="T_0888e_row3_col3" class="data row3 col3" >0.5042</td>
#       <td id="T_0888e_row3_col4" class="data row3 col4" >796</td>
#       <td id="T_0888e_row3_col5" class="data row3 col5" >2327</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row4_col0" class="data row4 col0" >DE</td>
#       <td id="T_0888e_row4_col1" class="data row4 col1" >R 300.14</td>
#       <td id="T_0888e_row4_col2" class="data row4 col2" >Bremsen</td>
#       <td id="T_0888e_row4_col3" class="data row4 col3" >0.5011</td>
#       <td id="T_0888e_row4_col4" class="data row4 col4" >1635</td>
#       <td id="T_0888e_row4_col5" class="data row4 col5" >4332</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row5_col0" class="data row5 col0" >DE</td>
#       <td id="T_0888e_row5_col1" class="data row5 col1" >R 300.6</td>
#       <td id="T_0888e_row5_col2" class="data row5 col2" >Zugfahrten</td>
#       <td id="T_0888e_row5_col3" class="data row5 col3" >0.4911</td>
#       <td id="T_0888e_row5_col4" class="data row5 col4" >852</td>
#       <td id="T_0888e_row5_col5" class="data row5 col5" >2514</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row6_col0" class="data row6 col0" >DE</td>
#       <td id="T_0888e_row6_col1" class="data row6 col1" >R 300.5</td>
#       <td id="T_0888e_row6_col2" class="data row6 col2" >Zugvorbereitung</td>
#       <td id="T_0888e_row6_col3" class="data row6 col3" >0.4907</td>
#       <td id="T_0888e_row6_col4" class="data row6 col4" >1012</td>
#       <td id="T_0888e_row6_col5" class="data row6 col5" >2791</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row7_col0" class="data row7 col0" >DE</td>
#       <td id="T_0888e_row7_col1" class="data row7 col1" >R 300.3</td>
#       <td id="T_0888e_row7_col2" class="data row7 col2" >Kommunikation Anordnungen und Uebermittlung</td>
#       <td id="T_0888e_row7_col3" class="data row7 col3" >0.4624</td>
#       <td id="T_0888e_row7_col4" class="data row7 col4" >1243</td>
#       <td id="T_0888e_row7_col5" class="data row7 col5" >2899</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row8_col0" class="data row8 col0" >DE</td>
#       <td id="T_0888e_row8_col1" class="data row8 col1" >R 300.15</td>
#       <td id="T_0888e_row8_col2" class="data row8 col2" >Besondere Betriebsformen</td>
#       <td id="T_0888e_row8_col3" class="data row8 col3" >0.4393</td>
#       <td id="T_0888e_row8_col4" class="data row8 col4" >312</td>
#       <td id="T_0888e_row8_col5" class="data row8 col5" >694</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row9_col0" class="data row9 col0" >DE</td>
#       <td id="T_0888e_row9_col1" class="data row9 col1" >R 300.1</td>
#       <td id="T_0888e_row9_col2" class="data row9 col2" >Grundlagen</td>
#       <td id="T_0888e_row9_col3" class="data row9 col3" >0.4193</td>
#       <td id="T_0888e_row9_col4" class="data row9 col4" >1436</td>
#       <td id="T_0888e_row9_col5" class="data row9 col5" >2987</td>
#     </tr>
#     <tr>
#       <td id="T_0888e_row10_col0" class="data row10 col0" >DE</td>
#       <td id="T_0888e_row10_col1" class="data row10 col1" >R 300.10</td>
# Summary — mean Gini per language:
#             mean     min     max
# language
# DE        0.4333  0.2687  0.6153
# FR        0.5365  0.3769  0.6916
# IT        0.5314  0.3605  0.6909

# %% [markdown]
# ## Section 8 — Domain Specificity: FDV vs. Reference Corpus
#
# Set `FETCH_WIKIPEDIA = True` in Section 0 to enable this section.

# %%
WIKI_ARTICLES = {
    "de": [
        "Wetter", "Geschichte_der_Schweiz", "Landwirtschaft", "Musik",
        "Schule", "Gesundheit", "Tourismus", "Literatur", "Sport", "Mathematik",
    ],
    "fr": [
        "M%C3%A9t%C3%A9o", "Histoire_de_la_Suisse", "Agriculture", "Musique",
        "%C3%89cole", "Sant%C3%A9", "Tourisme", "Litt%C3%A9rature", "Sport", "Math%C3%A9matiques",
    ],
    "it": [
        "Meteo", "Storia_della_Svizzera", "Agricoltura", "Musica",
        "Scuola", "Salute", "Turismo", "Letteratura", "Sport", "Matematica",
    ],
}

def fetch_wikipedia_text(lang: str, title: str) -> str:
    url = (
        f"https://{lang}.wikipedia.org/w/api.php"
        f"?action=query&prop=extracts&explaintext=1"
        f"&titles={title}&format=json"
    )
    req = urllib.request.Request(url, headers={"User-Agent": "FDV-RAG-Explorer/1.0"})
    try:
        with urllib.request.urlopen(req, timeout=15) as r:
            data = json.loads(r.read().decode("utf-8"))
        pages = data["query"]["pages"]
        return next(iter(pages.values())).get("extract", "")
    except Exception as e:
        print(f"    Warning: could not fetch {lang}:{title} — {e}")
        return ""


if not FETCH_WIKIPEDIA:
    print("FETCH_WIKIPEDIA is False — set it to True in Section 0 to run this section.")
else:
    overlap_summary = []

    for lang in LANGUAGES:
        print(f"\nFetching Wikipedia articles for {lang.upper()}...")
        wiki_texts = []
        for title in WIKI_ARTICLES[lang]:
            text = fetch_wikipedia_text(lang, title)
            if text:
                wiki_texts.append(text)
                print(f"    {title}: {len(text):,} chars")

        if not wiki_texts:
            print(f"  No Wikipedia content fetched for {lang.upper()} — skipping domain analysis.")
            overlap_summary.append({"Language": lang.upper(), "FDV vocab overlap with Wikipedia (%)": "n/a"})
            continue

        wiki_tokens = tokenize(" ".join(wiki_texts))
        wiki_freq   = Counter(wiki_tokens)
        wiki_vocab  = set(wiki_tokens)
        wiki_total  = sum(wiki_freq.values())

        fdv_text    = " ".join(c["text"] for c in chunks_by_lang[lang])
        fdv_tokens  = tokenize(fdv_text)
        fdv_freq    = Counter(fdv_tokens)
        fdv_vocab   = set(fdv_tokens)
        fdv_total   = sum(fdv_freq.values())

        overlap_pct = 100 * len(fdv_vocab & wiki_vocab) / len(fdv_vocab)
        overlap_summary.append({"Language": lang.upper(), "FDV vocab overlap with Wikipedia (%)": f"{overlap_pct:.1f}"})

        # Keyness: log2 ratio of relative frequencies
        keyness = {}
        for w in fdv_vocab:
            f_fdv  = fdv_freq.get(w, 0) / fdv_total
            f_wiki = wiki_freq.get(w, 1e-9) / wiki_total
            keyness[w] = np.log2(f_fdv / f_wiki)

        top_key = sorted(keyness.items(), key=lambda x: x[1], reverse=True)[:30]
        print(f"  {lang.upper()} — top domain-specific terms:")
        print("  ", ", ".join(w for w, _ in top_key))

        # Log-log scatter
        common = fdv_vocab & wiki_vocab
        x_vals = [wiki_freq.get(w, 1) / wiki_total for w in common]
        y_vals = [fdv_freq.get(w, 1)  / fdv_total  for w in common]

        fig, ax = plt.subplots(figsize=(7, 6))
        ax.scatter(x_vals, y_vals, s=5, alpha=0.4, color="steelblue")
        ax.set_xscale("log")
        ax.set_yscale("log")
        ax.set_xlabel("Wikipedia relative frequency")
        ax.set_ylabel("FDV relative frequency")
        ax.set_title(f"Log-log vocabulary scatter — {lang.upper()}")
        keyness_common = {w: keyness[w] for w in common}
        for w, _ in sorted(keyness_common.items(), key=lambda x: x[1], reverse=True)[:10]:
            xi = wiki_freq.get(w, 1) / wiki_total
            yi = fdv_freq.get(w, 1)  / fdv_total
            ax.annotate(w, (xi, yi), fontsize=7)
        plt.tight_layout()
        plt.show()

    print("\n" + "="*50)
    print("Vocabulary overlap summary")
    display(pd.DataFrame(overlap_summary))
# Out:
# Fetching Wikipedia articles for DE...
#     Wetter: 14,843 chars
#     Geschichte_der_Schweiz: 137,943 chars
#     Landwirtschaft: 37,268 chars
#     Musik: 111,754 chars
#     Schule: 39,165 chars
#     Gesundheit: 10,555 chars
#     Tourismus: 62,568 chars
#     Literatur: 60,419 chars
#     Sport: 20,950 chars
#     Mathematik: 25,518 chars
#   DE — top domain-specific terms:
#    fahrt, fahrzeuge, halt, zustimmung, gleis, rangierbewegungen, weiche, strecke, geschwindigkeit, befahren, bremse, rangierbewegung, züge, dürfen, betriebsvorschriften, bremsen, fahrzeugen, signalen, höchstgeschwindigkeit, hauptleitung, triebfahrzeuge, hauptsignal, trambetrieb, gleise, sicherheitsmassnahmen, fahrzeug, arbeitsstelle, fahrweg, bremsprobe, vorsignal
# Fetching Wikipedia articles for FR...
#     Warning: could not fetch fr:M%C3%A9t%C3%A9o — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Histoire_de_la_Suisse — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Agriculture — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Musique — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:%C3%89cole — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Sant%C3%A9 — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Tourisme — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Litt%C3%A9rature — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Sport — HTTP Error 429: Too Many Requests
#     Warning: could not fetch fr:Math%C3%A9matiques — HTTP Error 429: Too Many Requests
#   No Wikipedia content fetched for FR — skipping domain analysis.
#
# Fetching Wikipedia articles for IT...
#     Warning: could not fetch it:Meteo — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Storia_della_Svizzera — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Agricoltura — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Musica — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Scuola — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Salute — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Turismo — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Letteratura — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Sport — HTTP Error 429: Too Many Requests
#     Warning: could not fetch it:Matematica — HTTP Error 429: Too Many Requests
#   No Wikipedia content fetched for IT — skipping domain analysis.
#
# ==================================================
# Vocabulary overlap summary
#   Language FDV vocab overlap with Wikipedia (%)
# 0       DE                                 26.1
# 1       FR                                  n/a
# 2       IT                                  n/a
